# %% [markdown]
# # Must-visit places for foodies in european capitals

# %% [markdown]
# Capstone Project - Week 4
#
#
# Final Report – The Battle of the Neighborhoods

# %%
PATH = "C:/Users/ana roque/Desktop/Lolitinha/SKILLS/Capstone/"
Image(filename = PATH + "food.jpg", width=1000, height=1000)

# %% [markdown]
# ### Index
#
# 1. Introduction/Business Problem
#
#
#
# 2. Data

# %% [markdown]
# ### 1. Introduction/Business Problem

# %% [markdown]
# A foodie is a person who eats food not only out of hunger but due to their interest or hobby and passionate about food. Different cultures and cuisines all over the World provide exquisite experiences and typical foodie interests and activities include travelling around the world and discover a whole new set of cultural gastronomical experiences. Therefore, this project aims to look for food-related venues with particular restaurants in the capitals of european countries, cluster them and ultimately reveal the different cities in terms of food venues, even if they have closer geography.
#
#
# So, if you're a food lover planning your next big adventure, then we've got you covered. Whether you fancy indulging in the finest fresh seafood or simply sampling new twists on your favourite cuisines, check out our suggestions to the best foodie destinations in Europe to get on your bucket list.

# %% [markdown]
# ### 2. Data

# %% [markdown]
# This section aims to present the sources of the datasets require to achieve the aim of this project. In the final report we'll provide a more extensive description of the datasets. So, to explore this topic, we will need two datasets:
#
#
# 1) one of them should contain the coordinates of the european capital cities. So, we downloaded the .cvs file available at
# http://techslides.com/list-of-countries-and-capitals. After importing the data, we filtered it by "Continent Name"--"Europe". Note that we only considered the countries that are listed as "Sovereign states" in this webpage https://en.wikipedia.org/wiki/Category:Capitals_in_Europe.
#
# 2) then, we need to acquired location data to explore the nearby restaurant venues from the Foursquare API. Using the "explore" option, we look for top 5 restaurant venues in 5 km radius for each city center and we get "Venue", "Venue Latitude", "Venue Longitude" and "Venue Category".
